# %% [markdown]
# <a href="https://colab.research.google.com/github/W-teddy/First-/blob/main/Time_Series_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imported dependencies

# %%
pip install prophet

# %%
import prophet
import pandas as pd

import warnings;
warnings.simplefilter('ignore')

# %%
from prophet import Prophet

# %% [markdown]
# Imported data

# %%
df=pd.read_csv("dataset.csv")

# %% [markdown]
# Preprocessing

# %%
df.head()

# %%
df.describe()

# %%
print(df['Product'].unique())
print(df['Store'].unique())
# Out:
# [2667437]
# ['QLD_CW_ST0203']

# %%
df['Year'] = df['Time Date'].apply(lambda x: str(x)[-4:])
df['Month'] = df['Time Date'].apply(lambda x: str(x)[-6:-4])
df['Day'] = df['Time Date'].apply(lambda x: str(x)[:-6])
df['ds'] = pd.DatetimeIndex(df['Year']+'-'+df['Month']+'-'+df['Day'])

# %%
df = df.loc[(df['Product']==2667437) & (df['Store']=='QLD_CW_ST0203')]
df.drop(['Time Date', 'Product', 'Store', 'Year', 'Month', 'Day'], axis=1, inplace=True)
df.columns = ['y', 'ds']

# %%
df.head()

# %%
m = Prophet(interval_width=0.95, daily_seasonality=True)
model = m.fit(df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9an9wbd5/ulx_65nd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9an9wbd5/8k8x8bb1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75868', 'data', 'file=/tmp/tmp9an9wbd5/ulx_65nd.json', 'init=/tmp/tmp9an9wbd5/8k8x8bb1.json', 'output', 'file=/tmp/tmp9an9wbd5/prophet_modelplc9f1vq/prophet_model-20230804100503.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:05:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:05:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=4)

# %%
t=m.predict(future)

# %%
t.describe()
# Out:
#              trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# count  1084.000000  1084.000000  1084.000000  1084.000000  1084.000000
# mean   3560.633858  2454.655177  5639.044596  3560.633842  3560.633871
# std     325.965818  1188.826376  1186.771859   325.965788   325.965839
# min    3042.561512   494.411975  3653.695721  3042.561512  3042.561512
# 25%    3264.157357  1349.524677  4541.927044  3264.157357  3264.157357
# 50%    3553.725295  2154.678158  5365.607040  3553.725295  3553.725295
# 75%    3844.656953  3609.668351  6783.715404  3844.656953  3844.656953
# max    4135.010016  4446.199678  7634.955029  4134.997984  4135.019778
#
#        additive_terms  additive_terms_lower  additive_terms_upper  \
# count     1084.000000           1084.000000           1084.000000
# mean       484.791720            484.791720            484.791720
# std       1122.903440           1122.903440           1122.903440
# ...

# %%
future.describe()
# Out:
#                          ds
# count                  1084
# unique                 1084
# top     2018-01-01 00:00:00
# freq                      1
# first   2018-01-01 00:00:00
# last    2020-12-20 00:00:00

# %%
t.head()
# Out:
#           ds        trend  yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2018-01-01  3042.561512  849.094720  3951.286115  3042.561512  3042.561512
# 1 2018-01-02  3043.293094  832.401436  3908.147516  3043.293094  3043.293094
# 2 2018-01-03  3044.024676  738.794188  3986.452509  3044.024676  3044.024676
# 3 2018-01-04  3044.756258  794.561160  4094.880581  3044.756258  3044.756258
# 4 2018-01-05  3045.487839  936.042384  4007.502777  3045.487839  3045.487839
#
#    additive_terms  additive_terms_lower  additive_terms_upper       daily  \
# 0     -638.399466           -638.399466           -638.399466  471.949669
# 1     -648.583698           -648.583698           -648.583698  471.949669
# 2     -622.804684           -622.804684           -622.804684  471.949669
# 3     -575.884282           -575.884282           -575.884282  471.949669
# 4     -611.942497           -611.942497           -611.942497  471.949669
#
# ...
